# %% [markdown]
# # Get headers and cluster the files

# %%
# sources: https://itk.org/ITKExamples/src/IO/GDCM/ReadAndPrintDICOMTags/Documentation.html
#          https://itk.org/ITKExamples/src/IO/GDCM/ReadDICOMSeriesAndWrite3DImage/Documentation.html

import os
import sys
import shutil
import itk
import SimpleITK as sitk
import zipfile
import pickle
import _pickle as pickle2
import numpy as np

# %% [markdown]
# ## Extract metadata from DICOMs

# %%
# fetch the path to the  data
filepath = './in/all/'
savepath = './in/'
list_files = os.listdir(filepath)#[:50]
#
list_getkeys      = ['0008|0022', '0008|0060', '0008|0070', '0008|0080',
                     '0008|1010', '0008|1090', '0010|0020', '0018|0087',
                     '0010|1010', '0010|1020', '0010|1030',
                     '0018|0050', '0018|0088', '0028|0030',
                     '0018|0080', '0018|0081', '0018|0083',
                     '0018|0084', '0018|1314', 
                     '0018|0022', '0018|0025']
list_getkeys_name = ['Acquisition date', 'Modality',                'Manufacturer',     'Institution name',
                     'Station Name',     'Manufacturer Model Name', 'Patient ID',       'Magnetic Field Strength',
                     'Patient Age',      'Patient Size',            'Patient Weight',
                     'Slice Thickness',  'Spacing between Slices',  'Pixel Spacing',      # Image resolution
                     'Repetition Time',  'Echo Time',               'Number of Average',
                     'Image Frequency',  'Flip Angle',
                     'Scan Options',     'Angio Flag'] # scan options -> fat suppression
#
patients_data = [dict() for i in range(len(list_files))]
# Initialize some data
for (count, f) in enumerate(list_files):
    patients_data[count]['file'] = filepath + f
    #
    full_name = filepath + f
    dirName   = full_name + '/' + os.listdir(full_name)[0]
    #
    print(f'{count}/{len(list_files)} - Reading: {dirName}')
    # Read DICOM
    PixelType = itk.ctype("signed short")
    Dimension = 3
    ImageType = itk.Image[PixelType, Dimension]
    namesGenerator = itk.GDCMSeriesFileNames.New()
    namesGenerator.SetUseSeriesDetails(True)
    namesGenerator.SetDirectory(dirName)
    fileNames = namesGenerator.GetInputFileNames()
    reader    = itk.ImageSeriesReader[ImageType].New()
    dicomIO   = itk.GDCMImageIO.New()
    dicomIO.LoadPrivateTagsOn()
    reader.SetImageIO(dicomIO)
    reader.SetFileNames(fileNames)
    try:
        reader.Update()
    except:
        print("Error occured while reading DICOMs in: " + f)
        continue
    metadata = dicomIO.GetMetaDataDictionary()
    tagkeys = metadata.GetKeys() # get all keys

    for (i, tagkey) in enumerate(list_getkeys):
        # Note the [] operator for the key
        try:
            tagvalue = metadata[tagkey]
            #print(list_getkeys_name[i] + ": " + str(tagvalue))
            patients_data[count][list_getkeys_name[i]] = tagvalue
        except:
            patients_data[count][list_getkeys_name[i]] = 'None'
            print("Cannot pass specialized value " + tagkey + " into metadadictionary")
with open(savepath + 'headerDICOMs', 'wb') as wf:
    pickle.dump(patients_data, wf)
# Out:
# 0/1313 - Reading: ./in/all/aic 22 0104/282635
# 1/1313 - Reading: ./in/all/aic 22 0112/282637
# 2/1313 - Reading: ./in/all/aic 22 0113/282638
# 3/1313 - Reading: ./in/all/aic 22 0117/282641
# 4/1313 - Reading: ./in/all/aic 22 0118/282642
# 5/1313 - Reading: ./in/all/aic 22 0119/282643
# 6/1313 - Reading: ./in/all/aic 22 0121/283143
# 7/1313 - Reading: ./in/all/aic 22 0122/282645
# 8/1313 - Reading: ./in/all/aic 22 0125/282647
# 9/1313 - Reading: ./in/all/aic 22 0126/282648
# 10/1313 - Reading: ./in/all/aic 22 0127/282649
# 11/1313 - Reading: ./in/all/aic 22 0128/282650
# 12/1313 - Reading: ./in/all/aic 22 0131/282652
# 13/1313 - Reading: ./in/all/aic 22 0133/282654
# 14/1313 - Reading: ./in/all/aic 22 0134/282655
# 15/1313 - Reading: ./in/all/aic 22 0136/282656
# 16/1313 - Reading: ./in/all/aic 22 0142/282714
# 17/1313 - Reading: ./in/all/aic 22 0145/282717
# 18/1313 - Reading: ./in/all/aic 22 0146/291799
# 19/1313 - Reading: ./in/all/aic 22 0147/282743
# 20/1313 - Reading: ./in/all/aic 22 0148/282744
# 21/1313 - Reading: ./in/all/AIC _ 19 _0056/258380
# Cannot pass specialized value 0010|1020 into metadadictionary
# 22/1313 - Reading: ./in/all/AIC _ 19_0036/254540
# 23/1313 - Reading: ./in/all/AIC _19_0035/251970
# Cannot pass specialized value 0010|1020 into metadadictionary
# 24/1313 - Reading: ./in/all/AIC _19_0038/297084
# 25/1313 - Reading: ./in/all/AIC _19_0048/297087
# Cannot pass specialized value 0010|1020 into metadadictionary
# 26/1313 - Reading: ./in/all/AIC-05-0096/260654
# Cannot pass specialized value 0010|1020 into metadadictionary
# 27/1313 - Reading: ./in/all/AIC-05-0113/276721
# Cannot pass specialized value 0010|1020 into metadadictionary
# 28/1313 - Reading: ./in/all/AIC-05-0114/276722
# Cannot pass specialized value 0010|1020 into metadadictionary
# 29/1313 - Reading: ./in/all/AIC-05-0123/276749
# Cannot pass specialized value 0010|1020 into metadadictionary
# 30/1313 - Reading: ./in/all/AIC-05-0124/276792
# Cannot pass specialized value 0010|1020 into metadadictionary
# 31/1313 - Reading: ./in/all/AIC-05-0136/336732
# Cannot pass specialized value 0010|1020 into metadadictionary
# 32/1313 - Reading: ./in/all/AIC-05-126/276796
# Cannot pass specialized value 0010|1020 into metadadictionary
# 33/1313 - Reading: ./in/all/AIC-05-127/276799
# Cannot pass specialized value 0010|1020 into metadadictionary
# 34/1313 - Reading: ./in/all/AIC-05-129/276805
# Cannot pass specialized value 0010|1020 into metadadictionary
# 35/1313 - Reading: ./in/all/AIC-05-131/336637
# Cannot pass specialized value 0010|1020 into metadadictionary
# 36/1313 - Reading: ./in/all/AIC-05_0103/260619
# Cannot pass specialized value 0010|1020 into metadadictionary
# 37/1313 - Reading: ./in/all/AIC-08-0169/237330
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0010|1030 into metadadictionary
# 38/1313 - Reading: ./in/all/AIC-22-0077/280961
# 39/1313 - Reading: ./in/all/aic-22-0108/275793
# 40/1313 - Reading: ./in/all/AIC-22-0110/275795
# 41/1313 - Reading: ./in/all/AIC-22-0111/275796
# 42/1313 - Reading: ./in/all/AIC_ 19 _0031/251966
# 43/1313 - Reading: ./in/all/AIC_ 19_0037/251868
# 44/1313 - Reading: ./in/all/AIC_01_0001/187833
# 45/1313 - Reading: ./in/all/AIC_01_0002/187933
# 46/1313 - Reading: ./in/all/AIC_01_0003/187963
# 47/1313 - Reading: ./in/all/AIC_01_0005/187947
# 48/1313 - Reading: ./in/all/AIC_01_0006/187936
# 49/1313 - Reading: ./in/all/AIC_01_0008/187955
# 50/1313 - Reading: ./in/all/AIC_01_0011/200812
# Cannot pass specialized value 0018|0025 into metadadictionary
# 51/1313 - Reading: ./in/all/AIC_01_0012/187971
# 52/1313 - Reading: ./in/all/AIC_01_0013/187976
# 53/1313 - Reading: ./in/all/AIC_01_0014/187983
# 54/1313 - Reading: ./in/all/AIC_01_0015/187993
# 55/1313 - Reading: ./in/all/AIC_01_0016/187998
# 56/1313 - Reading: ./in/all/AIC_01_0017/188893
# 57/1313 - Reading: ./in/all/AIC_01_0018/198884
# 58/1313 - Reading: ./in/all/AIC_01_0020/190325
# Cannot pass specialized value 0010|1020 into metadadictionary
# 59/1313 - Reading: ./in/all/AIC_01_0021/190326
# Cannot pass specialized value 0018|0087 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0010|1030 into metadadictionary
# Cannot pass specialized value 0018|0088 into metadadictionary
# Cannot pass specialized value 0018|0080 into metadadictionary
# Cannot pass specialized value 0018|0081 into metadadictionary
# Cannot pass specialized value 0018|0083 into metadadictionary
# Cannot pass specialized value 0018|0084 into metadadictionary
# Cannot pass specialized value 0018|1314 into metadadictionary
# Cannot pass specialized value 0018|0022 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 60/1313 - Reading: ./in/all/AIC_01_0022/195837
# 61/1313 - Reading: ./in/all/AIC_01_0023/195834
# 62/1313 - Reading: ./in/all/AIC_01_0024/195831
# 63/1313 - Reading: ./in/all/AIC_01_0027/196538
# 64/1313 - Reading: ./in/all/AIC_01_0028/196573
# 65/1313 - Reading: ./in/all/AIC_01_0029/196575
# Cannot pass specialized value 0008|0080 into metadadictionary
# 66/1313 - Reading: ./in/all/AIC_01_0034/198450
# 67/1313 - Reading: ./in/all/AIC_01_0036/198741
# 68/1313 - Reading: ./in/all/AIC_01_0037/198278
# 69/1313 - Reading: ./in/all/AIC_01_0038/200830
# 70/1313 - Reading: ./in/all/AIC_01_0039/199027
# 71/1313 - Reading: ./in/all/AIC_01_0040/198995
# 72/1313 - Reading: ./in/all/AIC_01_0041/200838
# 73/1313 - Reading: ./in/all/AIC_01_0043/202022
# 74/1313 - Reading: ./in/all/AIC_01_0044/201220
# 75/1313 - Reading: ./in/all/AIC_01_0045/201226
# 76/1313 - Reading: ./in/all/AIC_01_0046/207297
# 77/1313 - Reading: ./in/all/AIC_01_0047/207335
# Cannot pass specialized value 0018|0025 into metadadictionary
# 78/1313 - Reading: ./in/all/AIC_01_0048/207350
# Cannot pass specialized value 0018|0025 into metadadictionary
# 79/1313 - Reading: ./in/all/AIC_01_0049/207353
# 80/1313 - Reading: ./in/all/AIC_01_0050/207356
# 81/1313 - Reading: ./in/all/AIC_01_0052/207362
# Cannot pass specialized value 0018|0025 into metadadictionary
# 82/1313 - Reading: ./in/all/AIC_01_0053/207363
# 83/1313 - Reading: ./in/all/AIC_01_0054/207388
# 84/1313 - Reading: ./in/all/AIC_01_0055/208759
# Cannot pass specialized value 0018|0025 into metadadictionary
# 85/1313 - Reading: ./in/all/AIC_01_0061/219592
# Cannot pass specialized value 0018|0025 into metadadictionary
# 86/1313 - Reading: ./in/all/AIC_01_0062/219619
# Cannot pass specialized value 0018|0025 into metadadictionary
# 87/1313 - Reading: ./in/all/AIC_01_0063/221651
# 88/1313 - Reading: ./in/all/AIC_01_0065/224375
# 89/1313 - Reading: ./in/all/AIC_01_0066/224387
# 90/1313 - Reading: ./in/all/AIC_01_0067/224428
# 91/1313 - Reading: ./in/all/AIC_01_0068/224431
# Cannot pass specialized value 0018|0025 into metadadictionary
# 92/1313 - Reading: ./in/all/AIC_01_0070/228503
# Cannot pass specialized value 0018|0025 into metadadictionary
# 93/1313 - Reading: ./in/all/AIC_01_0075/235538
# Cannot pass specialized value 0018|0025 into metadadictionary
# 94/1313 - Reading: ./in/all/AIC_01_0076/246886
# 95/1313 - Reading: ./in/all/AIC_01_0077/246885
# Cannot pass specialized value 0018|0025 into metadadictionary
# 96/1313 - Reading: ./in/all/AIC_01_0078/246892
# 97/1313 - Reading: ./in/all/AIC_01_0079/246967
# 98/1313 - Reading: ./in/all/AIC_01_0082/246995
# 99/1313 - Reading: ./in/all/AIC_01_0083/254380
# 100/1313 - Reading: ./in/all/AIC_01_0084/254414
# Cannot pass specialized value 0018|0025 into metadadictionary
# 101/1313 - Reading: ./in/all/AIC_01_0085/254441
# Cannot pass specialized value 0018|0025 into metadadictionary
# 102/1313 - Reading: ./in/all/AIC_01_0086/254456
# Cannot pass specialized value 0018|0025 into metadadictionary
# 103/1313 - Reading: ./in/all/AIC_01_0087/254482
# Cannot pass specialized value 0018|0025 into metadadictionary
# 104/1313 - Reading: ./in/all/AIC_01_0088/254542
# 105/1313 - Reading: ./in/all/AIC_01_0089/254556
# 106/1313 - Reading: ./in/all/AIC_01_0090/254565
# Cannot pass specialized value 0018|0025 into metadadictionary
# 107/1313 - Reading: ./in/all/AIC_01_0091/254593
# 108/1313 - Reading: ./in/all/AIC_01_0092/254598
# 109/1313 - Reading: ./in/all/AIC_01_0093/261074
# 110/1313 - Reading: ./in/all/AIC_01_0095/261225
# 111/1313 - Reading: ./in/all/AIC_01_0096/261228
# 112/1313 - Reading: ./in/all/AIC_01_0098/261960
# 113/1313 - Reading: ./in/all/AIC_01_0100/261996
# Cannot pass specialized value 0018|0025 into metadadictionary
# 114/1313 - Reading: ./in/all/AIC_01_0101/307209
# 115/1313 - Reading: ./in/all/AIC_01_0102/262004
# 116/1313 - Reading: ./in/all/AIC_01_0117/263318
# Cannot pass specialized value 0018|0025 into metadadictionary
# 117/1313 - Reading: ./in/all/AIC_01_0118/263354
# 118/1313 - Reading: ./in/all/AIC_01_0122/303023
# 119/1313 - Reading: ./in/all/AIC_01_0124/307210
# 120/1313 - Reading: ./in/all/AIC_01_0134/307076
# 121/1313 - Reading: ./in/all/AIC_01_0135/307079
# 122/1313 - Reading: ./in/all/AIC_01_0136/307082
# 123/1313 - Reading: ./in/all/AIC_01_0138/308313
# Cannot pass specialized value 0018|0025 into metadadictionary
# 124/1313 - Reading: ./in/all/AIC_01_0139/307216
# 125/1313 - Reading: ./in/all/AIC_01_0143/307227
# 126/1313 - Reading: ./in/all/AIC_01_0145/308315
# 127/1313 - Reading: ./in/all/AIC_01_0151/307654
# 128/1313 - Reading: ./in/all/AIC_01_0152/307665
# 129/1313 - Reading: ./in/all/AIC_01_0153/307668
# Cannot pass specialized value 0018|0025 into metadadictionary
# 130/1313 - Reading: ./in/all/AIC_01_0154/307674
# Cannot pass specialized value 0018|0025 into metadadictionary
# 131/1313 - Reading: ./in/all/AIC_01_0155/307682
# Cannot pass specialized value 0018|0025 into metadadictionary
# 132/1313 - Reading: ./in/all/AIC_01_0158/307834
# 133/1313 - Reading: ./in/all/AIC_01_0159/307835
# 134/1313 - Reading: ./in/all/AIC_01_0167/308038
# 135/1313 - Reading: ./in/all/AIC_01_0168/308043
# 136/1313 - Reading: ./in/all/AIC_01_0170/308052
# Cannot pass specialized value 0018|0025 into metadadictionary
# 137/1313 - Reading: ./in/all/AIC_01_0173/308130
# Cannot pass specialized value 0018|0025 into metadadictionary
# 138/1313 - Reading: ./in/all/AIC_01_0176/308172
# 139/1313 - Reading: ./in/all/AIC_01_0180/308175
# Cannot pass specialized value 0018|0025 into metadadictionary
# 140/1313 - Reading: ./in/all/AIC_01_0182/308176
# 141/1313 - Reading: ./in/all/AIC_01_0183/308178
# Cannot pass specialized value 0018|0025 into metadadictionary
# 142/1313 - Reading: ./in/all/AIC_01_0184/308181
# 143/1313 - Reading: ./in/all/AIC_01_0191/308233
# 144/1313 - Reading: ./in/all/AIC_01_0192/308237
# 145/1313 - Reading: ./in/all/AIC_01_0195/313886
# 146/1313 - Reading: ./in/all/AIC_01_0197/313898
# 147/1313 - Reading: ./in/all/AIC_01_0198/313901
# Cannot pass specialized value 0018|0025 into metadadictionary
# 148/1313 - Reading: ./in/all/AIC_01_0199/322410
# Cannot pass specialized value 0018|0025 into metadadictionary
# 149/1313 - Reading: ./in/all/AIC_01_0201/322417
# Cannot pass specialized value 0018|0025 into metadadictionary
# 150/1313 - Reading: ./in/all/AIC_01_0202/322419
# Cannot pass specialized value 0018|0025 into metadadictionary
# 151/1313 - Reading: ./in/all/AIC_01_0220/383594
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 152/1313 - Reading: ./in/all/AIC_01_0225/375836
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 153/1313 - Reading: ./in/all/AIC_01_0226/375837
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 154/1313 - Reading: ./in/all/AIC_01_0227/375838
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 155/1313 - Reading: ./in/all/AIC_01_0229/375840
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 156/1313 - Reading: ./in/all/AIC_01_0270/343861
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# 157/1313 - Reading: ./in/all/AIC_01_0279/344637
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 158/1313 - Reading: ./in/all/AIC_01_0294/346084
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 159/1313 - Reading: ./in/all/AIC_01_0325/344671
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# 160/1313 - Reading: ./in/all/AIC_01_0364/345252
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 161/1313 - Reading: ./in/all/AIC_01_0392/343729
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
#
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 203/1313 - Reading: ./in/all/AIC_03_0105/232327
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# 204/1313 - Reading: ./in/all/AIC_03_0106/232331
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# 205/1313 - Reading: ./in/all/AIC_03_0114/250251
# Cannot pass specialized value 0008|1010 into metadadictionary
# 206/1313 - Reading: ./in/all/AIC_03_0116/233469
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 207/1313 - Reading: ./in/all/AIC_03_0118/283342
# Cannot pass specialized value 0008|1010 into metadadictionary
# 208/1313 - Reading: ./in/all/AIC_03_0119/283345
# Cannot pass specialized value 0008|1010 into metadadictionary
# 209/1313 - Reading: ./in/all/AIC_03_0120/233807
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 210/1313 - Reading: ./in/all/AIC_03_0121/283349
# Cannot pass specialized value 0008|1010 into metadadictionary
# 211/1313 - Reading: ./in/all/AIC_03_0122/233491
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 212/1313 - Reading: ./in/all/AIC_03_0123/233712
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# 213/1313 - Reading: ./in/all/AIC_03_0124/233716
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 214/1313 - Reading: ./in/all/AIC_03_0125/233722
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# 215/1313 - Reading: ./in/all/AIC_03_0128/283352
# Cannot pass specialized value 0008|1010 into metadadictionary
# 216/1313 - Reading: ./in/all/AIC_03_0129/233811
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 217/1313 - Reading: ./in/all/AIC_03_0131/236495
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 218/1313 - Reading: ./in/all/AIC_03_0136/303403
# Cannot pass specialized value 0008|1010 into metadadictionary
# 219/1313 - Reading: ./in/all/AIC_03_0137/235450
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# 220/1313 - Reading: ./in/all/AIC_03_0138/236671
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 221/1313 - Reading: ./in/all/AIC_03_0139/307044
# 222/1313 - Reading: ./in/all/AIC_03_0140/250211
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 223/1313 - Reading: ./in/all/AIC_03_0141/250221
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 224/1313 - Reading: ./in/all/AIC_03_0144/250224
# Cannot pass specialized value 0008|1010 into metadadictionary
# 225/1313 - Reading: ./in/all/AIC_03_0146/250220
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 226/1313 - Reading: ./in/all/AIC_03_0147/250237
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 227/1313 - Reading: ./in/all/AIC_03_0148/250228
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 228/1313 - Reading: ./in/all/AIC_03_0150/283355
# Cannot pass specialized value 0008|1010 into metadadictionary
# 229/1313 - Reading: ./in/all/AIC_03_0151/250232
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 230/1313 - Reading: ./in/all/AIC_03_0152/250242
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 231/1313 - Reading: ./in/all/AIC_03_0156/283303
# Cannot pass specialized value 0008|1010 into metadadictionary
# 232/1313 - Reading: ./in/all/AIC_03_0159/283335
# Cannot pass specialized value 0008|1010 into metadadictionary
# 233/1313 - Reading: ./in/all/AIC_03_0160/283307
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 234/1313 - Reading: ./in/all/AIC_03_0163/283316
# Cannot pass specialized value 0008|1010 into metadadictionary
# 235/1313 - Reading: ./in/all/AIC_03_0164/283452
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 236/1313 - Reading: ./in/all/AIC_03_0165/283457
# Cannot pass specialized value 0008|1010 into metadadictionary
# 237/1313 - Reading: ./in/all/AIC_03_0166/283469
# Cannot pass specialized value 0008|1010 into metadadictionary
# 238/1313 - Reading: ./in/all/AIC_03_0169/283473
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 239/1313 - Reading: ./in/all/AIC_03_0171/295880
# Cannot pass specialized value 0008|1010 into metadadictionary
# 240/1313 - Reading: ./in/all/AIC_03_0172/295882
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 241/1313 - Reading: ./in/all/AIC_03_0173/295884
# Cannot pass specialized value 0008|1010 into metadadictionary
# 242/1313 - Reading: ./in/all/AIC_03_0174/307043
# 243/1313 - Reading: ./in/all/AIC_03_0175/295887
# Cannot pass specialized value 0008|1010 into metadadictionary
# 244/1313 - Reading: ./in/all/AIC_03_0176/312515
# 245/1313 - Reading: ./in/all/AIC_03_0177/295891
# Cannot pass specialized value 0008|1010 into metadadictionary
# 246/1313 - Reading: ./in/all/AIC_03_0179/295893
# Cannot pass specialized value 0008|1010 into metadadictionary
# 247/1313 - Reading: ./in/all/AIC_03_0181/295898
# Cannot pass specialized value 0008|1010 into metadadictionary
# 248/1313 - Reading: ./in/all/AIC_03_0182/339245
# 249/1313 - Reading: ./in/all/AIC_03_0185/321105
# 250/1313 - Reading: ./in/all/AIC_03_0188/303318
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# 251/1313 - Reading: ./in/all/AIC_03_0189/303323
# Cannot pass specialized value 0008|1010 into metadadictionary
# 252/1313 - Reading: ./in/all/AIC_03_0190/302760
# Cannot pass specialized value 0008|1010 into metadadictionary
# 253/1313 - Reading: ./in/all/AIC_03_0191/339247
# 254/1313 - Reading: ./in/all/AIC_03_0195/303399
# Cannot pass specialized value 0008|1010 into metadadictionary
# 255/1313 - Reading: ./in/all/AIC_03_0197/303401
# Cannot pass specialized value 0008|1010 into metadadictionary
# 256/1313 - Reading: ./in/all/AIC_04_0013/265489
# 257/1313 - Reading: ./in/all/AIC_04_0015/265487
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 258/1313 - Reading: ./in/all/AIC_04_0017/265485
# 259/1313 - Reading: ./in/all/AIC_04_0019/265483
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 260/1313 - Reading: ./in/all/AIC_04_0020/265482
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 261/1313 - Reading: ./in/all/AIC_04_0026/250348
# Cannot pass specialized value 0010|1020 into metadadictionary
# 262/1313 - Reading: ./in/all/AIC_04_0028/250346
# 263/1313 - Reading: ./in/all/AIC_04_0029/250305
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 264/1313 - Reading: ./in/all/AIC_04_0030/250304
# Cannot pass specialized value 0010|1020 into metadadictionary
# 265/1313 - Reading: ./in/all/AIC_04_0031/250260
# Cannot pass specialized value 0010|1020 into metadadictionary
# 266/1313 - Reading: ./in/all/AIC_04_0037/250256
# Cannot pass specialized value 0010|1020 into metadadictionary
# 267/1313 - Reading: ./in/all/AIC_04_0041/247421
# Cannot pass specialized value 0010|1020 into metadadictionary
# 268/1313 - Reading: ./in/all/AIC_04_0042/247417
# 269/1313 - Reading: ./in/all/AIC_04_0044/247731
# Cannot pass specialized value 0010|1020 into metadadictionary
# 270/1313 - Reading: ./in/all/AIC_04_0046/247693
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 271/1313 - Reading: ./in/all/AIC_04_0055/247804
# Cannot pass specialized value 0010|1020 into metadadictionary
# 272/1313 - Reading: ./in/all/AIC_04_0059/247347
# Cannot pass specialized value 0010|1020 into metadadictionary
# 273/1313 - Reading: ./in/all/AIC_04_0063/247348
# 274/1313 - Reading: ./in/all/AIC_04_0065/252311
# 275/1313 - Reading: ./in/all/AIC_04_0066/250608
# 276/1313 - Reading: ./in/all/AIC_04_0068/252823
# 277/1313 - Reading: ./in/all/AIC_04_0070/254536
# 278/1313 - Reading: ./in/all/AIC_04_0071/254537
# 279/1313 - Reading: ./in/all/AIC_04_0072/254499
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 280/1313 - Reading: ./in/all/AIC_04_0074/254497
# 281/1313 - Reading: ./in/all/AIC_04_0076/258996
# Cannot pass specialized value 0010|1020 into metadadictionary
# 282/1313 - Reading: ./in/all/AIC_04_0080/258993
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 283/1313 - Reading: ./in/all/AIC_04_0081/258992
# Cannot pass specialized value 0010|1020 into metadadictionary
# 284/1313 - Reading: ./in/all/AIC_04_0084/258989
# Cannot pass specialized value 0010|1020 into metadadictionary
# 285/1313 - Reading: ./in/all/AIC_04_0087/268350
# Cannot pass specialized value 0010|1020 into metadadictionary
# 286/1313 - Reading: ./in/all/AIC_04_0088/268338
# 287/1313 - Reading: ./in/all/AIC_04_0089/268337
# 288/1313 - Reading: ./in/all/AIC_04_0090/268893
# Cannot pass specialized value 0010|1020 into metadadictionary
# 289/1313 - Reading: ./in/all/AIC_04_0091/275252
# Cannot pass specialized value 0010|1020 into metadadictionary
# 290/1313 - Reading: ./in/all/AIC_04_0093/275253
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 291/1313 - Reading: ./in/all/AIC_04_0094/268641
# 292/1313 - Reading: ./in/all/AIC_04_0095/268642
# Cannot pass specialized value 0010|1020 into metadadictionary
# 293/1313 - Reading: ./in/all/AIC_04_0097/275251
# 294/1313 - Reading: ./in/all/AIC_04_0099/317465
# Cannot pass specialized value 0010|1020 into metadadictionary
# 295/1313 - Reading: ./in/all/AIC_04_0100/268892
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 296/1313 - Reading: ./in/all/AIC_04_0101/275259
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 297/1313 - Reading: ./in/all/AIC_04_0103/275250
# Cannot pass specialized value 0010|1020 into metadadictionary
# 298/1313 - Reading: ./in/all/AIC_04_0105/275255
# Cannot pass specialized value 0010|1020 into metadadictionary
# 299/1313 - Reading: ./in/all/AIC_04_0106/275260
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 300/1313 - Reading: ./in/all/AIC_04_0107/331507
# 301/1313 - Reading: ./in/all/AIC_04_0108/331508
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 302/1313 - Reading: ./in/all/AIC_04_0109/318134
# Cannot pass specialized value 0010|1020 into metadadictionary
# 303/1313 - Reading: ./in/all/AIC_04_0110/320714
# Cannot pass specialized value 0010|1020 into metadadictionary
# 304/1313 - Reading: ./in/all/AIC_04_0111/331510
# 305/1313 - Reading: ./in/all/AIC_04_0112/320716
# Cannot pass specialized value 0010|1020 into metadadictionary
# 306/1313 - Reading: ./in/all/AIC_04_0113/331511
# Cannot pass specialized value 0010|1020 into metadadictionary
# 307/1313 - Reading: ./in/all/AIC_04_0114/291822
# 308/1313 - Reading: ./in/all/AIC_04_0115/320718
# Cannot pass specialized value 0010|1020 into metadadictionary
# 309/1313 - Reading: ./in/all/AIC_04_0123/291821
# Cannot pass specialized value 0010|1020 into metadadictionary
# 310/1313 - Reading: ./in/all/AIC_04_0125/320720
# Cannot pass specialized value 0010|1020 into metadadictionary
# 311/1313 - Reading: ./in/all/AIC_04_0126/320721
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 312/1313 - Reading: ./in/all/AIC_04_0131/320725
# Cannot pass specialized value 0010|1020 into metadadictionary
# 313/1313 - Reading: ./in/all/AIC_04_0136/291844
# 314/1313 - Reading: ./in/all/AIC_04_0138/320727
# Cannot pass specialized value 0010|1020 into metadadictionary
# 315/1313 - Reading: ./in/all/AIC_04_0140/291872
# 316/1313 - Reading: ./in/all/AIC_04_0142/331527
# Cannot pass specialized value 0010|1020 into metadadictionary
# 317/1313 - Reading: ./in/all/AIC_04_0144/291840
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 318/1313 - Reading: ./in/all/AIC_04_0146/291890
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 319/1313 - Reading: ./in/all/AIC_04_0149/331528
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 320/1313 - Reading: ./in/all/AIC_04_0150/305382
# Cannot pass specialized value 0010|1020 into metadadictionary
# 321/1313 - Reading: ./in/all/AIC_04_0151/320836
# 322/1313 - Reading: ./in/all/AIC_04_0152/305380
# 323/1313 - Reading: ./in/all/AIC_04_0153/320797
# Cannot pass specialized value 0010|1020 into metadadictionary
# 324/1313 - Reading: ./in/all/AIC_05_0001/190847
# Cannot pass specialized value 0010|1020 into metadadictionary
# 325/1313 - Reading: ./in/all/AIC_05_0003/190667
# Cannot pass specialized value 0010|1020 into metadadictionary
# 326/1313 - Reading: ./in/all/AIC_05_0004/190676
# Cannot pass specialized value 0010|1020 into metadadictionary
# 327/1313 - Reading: ./in/all/AIC_05_0006/190860
# Cannot pass specialized value 0010|1020 into metadadictionary
# 328/1313 - Reading: ./in/all/AIC_05_0007/190686
# Cannot pass specialized value 0010|1020 into metadadictionary
# 329/1313 - Reading: ./in/all/AIC_05_0008/190854
# Cannot pass specialized value 0010|1020 into metadadictionary
# 330/1313 - Reading: ./in/all/AIC_05_0009/191333
# Cannot pass specialized value 0010|1020 into metadadictionary
# 331/1313 - Reading: ./in/all/AIC_05_0010/191342
# Cannot pass specialized value 0010|1020 into metadadictionary
# 332/1313 - Reading: ./in/all/AIC_05_00130/297993
# Cannot pass specialized value 0010|1020 into metadadictionary
# 333/1313 - Reading: ./in/all/AIC_05_0014/196649
# Cannot pass specialized value 0010|1020 into metadadictionary
# 334/1313 - Reading: ./in/all/AIC_05_0015/196656
# Cannot pass specialized value 0010|1020 into metadadictionary
# 335/1313 - Reading: ./in/all/AIC_05_0016/197123
# Cannot pass specialized value 0010|1020 into metadadictionary
# 336/1313 - Reading: ./in/all/AIC_05_0017/197132
# Cannot pass specialized value 0010|1020 into metadadictionary
# 337/1313 - Reading: ./in/all/AIC_05_0018/198261
# Cannot pass specialized value 0010|1020 into metadadictionary
# 338/1313 - Reading: ./in/all/AIC_05_0020/198325
# Cannot pass specialized value 0010|1020 into metadadictionary
# 339/1313 - Reading: ./in/all/AIC_05_0021/198369
# Cannot pass specialized value 0010|1020 into metadadictionary
# 340/1313 - Reading: ./in/all/AIC_05_0023/198916
# Cannot pass specialized value 0010|1020 into metadadictionary
# 341/1313 - Reading: ./in/all/AIC_05_0029/222977
# 342/1313 - Reading: ./in/all/AIC_05_0032/201150
# Cannot pass specialized value 0010|1020 into metadadictionary
# 343/1313 - Reading: ./in/all/AIC_05_0038/222983
# Cannot pass specialized value 0010|1020 into metadadictionary
# 344/1313 - Reading: ./in/all/AIC_05_0041/203510
# Cannot pass specialized value 0010|1020 into metadadictionary
# 345/1313 - Reading: ./in/all/AIC_05_0043/203547
# Cannot pass specialized value 0010|1020 into metadadictionary
# 346/1313 - Reading: ./in/all/AIC_05_0044/203516
# Cannot pass specialized value 0010|1020 into metadadictionary
# 347/1313 - Reading: ./in/all/AIC_05_0046/213717
# Cannot pass specialized value 0010|1020 into metadadictionary
# 348/1313 - Reading: ./in/all/AIC_05_0047/213721
# Cannot pass specialized value 0010|1020 into metadadictionary
# 349/1313 - Reading: ./in/all/AIC_05_0048/213725
# Cannot pass specialized value 0010|1020 into metadadictionary
# 350/1313 - Reading: ./in/all/AIC_05_0049/223170
# 351/1313 - Reading: ./in/all/AIC_05_0050/240492
# Cannot pass specialized value 0010|1020 into metadadictionary
# 352/1313 - Reading: ./in/all/AIC_05_0051/213726
# Cannot pass specialized value 0010|1020 into metadadictionary
# 353/1313 - Reading: ./in/all/AIC_05_0052/213735
# Cannot pass specialized value 0010|1020 into metadadictionary
# 354/1313 - Reading: ./in/all/AIC_05_0053/213738
# Cannot pass specialized value 0010|1020 into metadadictionary
# 355/1313 - Reading: ./in/all/AIC_05_0054/213744
# Cannot pass specialized value 0010|1020 into metadadictionary
# 356/1313 - Reading: ./in/all/AIC_05_0055/213743
# Cannot pass specialized value 0010|1020 into metadadictionary
# 357/1313 - Reading: ./in/all/AIC_05_0056/213748
# Cannot pass specialized value 0010|1020 into metadadictionary
# 358/1313 - Reading: ./in/all/AIC_05_0057/218465
# Cannot pass specialized value 0010|1020 into metadadictionary
# 359/1313 - Reading: ./in/all/AIC_05_0058/223177
# 360/1313 - Reading: ./in/all/AIC_05_0060/223184
# Cannot pass specialized value 0010|1020 into metadadictionary
# 361/1313 - Reading: ./in/all/AIC_05_0063/223191
# Cannot pass specialized value 0010|1020 into metadadictionary
# 362/1313 - Reading: ./in/all/AIC_05_0065/223204
# Cannot pass specialized value 0010|1020 into metadadictionary
# 363/1313 - Reading: ./in/all/AIC_05_0066/223207
# 364/1313 - Reading: ./in/all/AIC_05_0067/223215
# Cannot pass specialized value 0010|1020 into metadadictionary
# 365/1313 - Reading: ./in/all/AIC_05_0068/223218
# Cannot pass specialized value 0010|1020 into metadadictionary
# 366/1313 - Reading: ./in/all/AIC_05_0070/228584
# Cannot pass specialized value 0010|1020 into metadadictionary
# 367/1313 - Reading: ./in/all/AIC_05_0072/228604
# 368/1313 - Reading: ./in/all/AIC_05_0073/228606
# Cannot pass specialized value 0010|1020 into metadadictionary
# 369/1313 - Reading: ./in/all/AIC_05_0074/228614
# Cannot pass specialized value 0010|1020 into metadadictionary
# 370/1313 - Reading: ./in/all/AIC_05_0075/228620
# Cannot pass specialized value 0010|1020 into metadadictionary
# 371/1313 - Reading: ./in/all/AIC_05_0076/228625
# Cannot pass specialized value 0010|1020 into metadadictionary
# 372/1313 - Reading: ./in/all/AIC_05_0077/228632
# Cannot pass specialized value 0010|1020 into metadadictionary
# 373/1313 - Reading: ./in/all/AIC_05_0078/228638
# Cannot pass specialized value 0010|1020 into metadadictionary
# 374/1313 - Reading: ./in/all/AIC_05_0079/228676
# Cannot pass specialized value 0010|1020 into metadadictionary
# 375/1313 - Reading: ./in/all/AIC_05_0080/228571
# Cannot pass specialized value 0010|1020 into metadadictionary
# 376/1313 - Reading: ./in/all/AIC_05_0084/236674
# Cannot pass specialized value 0010|1020 into metadadictionary
# 377/1313 - Reading: ./in/all/AIC_05_0085/236687
# Cannot pass specialized value 0010|1020 into metadadictionary
# 378/1313 - Reading: ./in/all/AIC_05_0086/237638
# Cannot pass specialized value 0010|1020 into metadadictionary
# 379/1313 - Reading: ./in/all/AIC_05_0087/237642
# Cannot pass specialized value 0010|1020 into metadadictionary
# 380/1313 - Reading: ./in/all/AIC_05_0088/238131
# Cannot pass specialized value 0010|1020 into metadadictionary
# 381/1313 - Reading: ./in/all/AIC_05_0089/237650
# Cannot pass specialized value 0010|1020 into metadadictionary
# 382/1313 - Reading: ./in/all/AIC_05_0090/237662
# Cannot pass specialized value 0010|1020 into metadadictionary
# 383/1313 - Reading: ./in/all/AIC_05_0093/240489
# Cannot pass specialized value 0010|1020 into metadadictionary
# 384/1313 - Reading: ./in/all/AIC_05_0094/254679
# Cannot pass specialized value 0010|1020 into metadadictionary
# 385/1313 - Reading: ./in/all/AIC_05_0097/260657
# Cannot pass specialized value 0010|1020 into metadadictionary
# 386/1313 - Reading: ./in/all/AIC_05_0100/260616
# Cannot pass specialized value 0010|1020 into metadadictionary
# 387/1313 - Reading: ./in/all/AIC_05_0102/261542
# Cannot pass specialized value 0010|1020 into metadadictionary
# 388/1313 - Reading: ./in/all/AIC_05_0104/260622
# Cannot pass specialized value 0010|1020 into metadadictionary
# 389/1313 - Reading: ./in/all/aic_05_0105/261543
# Cannot pass specialized value 0010|1020 into metadadictionary
# 390/1313 - Reading: ./in/all/AIC_05_0106/261566
# Cannot pass specialized value 0010|1020 into metadadictionary
# 391/1313 - Reading: ./in/all/AIC_05_0107/261570
# Cannot pass specialized value 0010|1020 into metadadictionary
# 392/1313 - Reading: ./in/all/AIC_05_0108/261941
# Cannot pass specialized value 0010|1020 into metadadictionary
# 393/1313 - Reading: ./in/all/AIC_05_0112/276612
# Cannot pass specialized value 0010|1020 into metadadictionary
# 394/1313 - Reading: ./in/all/AIC_05_0116/276617
# Cannot pass specialized value 0010|1020 into metadadictionary
# 395/1313 - Reading: ./in/all/AIC_05_0138/298001
# Cannot pass specialized value 0010|1020 into metadadictionary
# 396/1313 - Reading: ./in/all/AIC_05_0139/298058
# Cannot pass specialized value 0010|1020 into metadadictionary
# 397/1313 - Reading: ./in/all/AIC_05_0140/298003
# Cannot pass specialized value 0010|1020 into metadadictionary
# 398/1313 - Reading: ./in/all/AIC_05_0141/298241
# Cannot pass specialized value 0010|1020 into metadadictionary
# 399/1313 - Reading: ./in/all/AIC_05_0142/298238
# Cannot pass specialized value 0010|1020 into metadadictionary
# 400/1313 - Reading: ./in/all/AIC_05_0143/298247
# Cannot pass specialized value 0010|1020 into metadadictionary
# 401/1313 - Reading: ./in/all/AIC_05_0144/298259
# Cannot pass specialized value 0010|1020 into metadadictionary
# 402/1313 - Reading: ./in/all/AIC_05_0145/298263
# Cannot pass specialized value 0010|1020 into metadadictionary
# 403/1313 - Reading: ./in/all/AIC_05_0147/298282
# Cannot pass specialized value 0010|1020 into metadadictionary
# 404/1313 - Reading: ./in/all/AIC_05_0149/298281
# Cannot pass specialized value 0010|1020 into metadadictionary
# 405/1313 - Reading: ./in/all/AIC_05_0150/298294
# Cannot pass specialized value 0010|1020 into metadadictionary
# 406/1313 - Reading: ./in/all/AIC_05_0151/298291
# Cannot pass specialized value 0010|1020 into metadadictionary
# 407/1313 - Reading: ./in/all/AIC_05_0153/298287
# Cannot pass specialized value 0010|1020 into metadadictionary
# 408/1313 - Reading: ./in/all/AIC_05_0154/298300
# Cannot pass specialized value 0010|1020 into metadadictionary
# 409/1313 - Reading: ./in/all/AIC_05_091/240483
# Cannot pass specialized value 0010|1020 into metadadictionary
# 410/1313 - Reading: ./in/all/AIC_05_092/240487
# Cannot pass specialized value 0010|1020 into metadadictionary
# 411/1313 - Reading: ./in/all/AIC_05_095/260518
# Cannot pass specialized value 0010|1020 into metadadictionary
# 412/1313 - Reading: ./in/all/AIC_05_098/260615
# Cannot pass specialized value 0010|1020 into metadadictionary
# 413/1313 - Reading: ./in/all/AIC_05_099/259042
# Cannot pass specialized value 0010|1020 into metadadictionary
# 414/1313 - Reading: ./in/all/AIC_05_111/259047
# Cannot pass specialized value 0010|1020 into metadadictionary
# 415/1313 - Reading: ./in/all/AIC_05_148/298275
# Cannot pass specialized value 0010|1020 into metadadictionary
# 416/1313 - Reading: ./in/all/AIC_06_0051/303059
# 417/1313 - Reading: ./in/all/AIC_07_0001/236657
# Cannot pass specialized value 0010|1020 into metadadictionary
# 418/1313 - Reading: ./in/all/AIC_07_0002/197040
# 419/1313 - Reading: ./in/all/AIC_07_0003/246964
# Cannot pass specialized value 0010|1020 into metadadictionary
# 420/1313 - Reading: ./in/all/AIC_07_0006/234649
# Cannot pass specialized value 0010|1020 into metadadictionary
# 421/1313 - Reading: ./in/all/AIC_07_0007/234646
# Cannot pass specialized value 0010|1020 into metadadictionary
# 422/1313 - Reading: ./in/all/AIC_07_0009/234642
# Cannot pass specialized value 0010|1020 into metadadictionary
# 423/1313 - Reading: ./in/all/AIC_07_0010/234640
# Cannot pass specialized value 0010|1020 into metadadictionary
# 424/1313 - Reading: ./in/all/AIC_07_0011/234638
# Cannot pass specialized value 0010|1020 into metadadictionary
# 425/1313 - Reading: ./in/all/AIC_07_0012/234636
# Cannot pass specialized value 0010|1020 into metadadictionary
# 426/1313 - Reading: ./in/all/AIC_07_0013/196648
# Cannot pass specialized value 0010|1020 into metadadictionary
# 427/1313 - Reading: ./in/all/AIC_07_0014/234631
# Cannot pass specialized value 0010|1020 into metadadictionary
# 428/1313 - Reading: ./in/all/AIC_07_0015/234629
# Cannot pass specialized value 0010|1020 into metadadictionary
# 429/1313 - Reading: ./in/all/AIC_07_0016/234627
# Cannot pass specialized value 0010|1020 into metadadictionary
# 430/1313 - Reading: ./in/all/AIC_07_0018/234625
# Cannot pass specialized value 0010|1020 into metadadictionary
# 431/1313 - Reading: ./in/all/AIC_07_0019/234622
# Cannot pass specialized value 0010|1020 into metadadictionary
# 432/1313 - Reading: ./in/all/AIC_07_0020/234621
# Cannot pass specialized value 0010|1020 into metadadictionary
# 433/1313 - Reading: ./in/all/AIC_07_0021/234618
# Cannot pass specialized value 0010|1020 into metadadictionary
# 434/1313 - Reading: ./in/all/AIC_07_0022/234617
# Cannot pass specialized value 0010|1020 into metadadictionary
# 435/1313 - Reading: ./in/all/AIC_07_0023/234615
# Cannot pass specialized value 0010|1020 into metadadictionary
# 436/1313 - Reading: ./in/all/AIC_07_0024/234613
# Cannot pass specialized value 0010|1020 into metadadictionary
# 437/1313 - Reading: ./in/all/AIC_07_0025/236167
# Cannot pass specialized value 0010|1020 into metadadictionary
# 438/1313 - Reading: ./in/all/AIC_07_0026/234608
# Cannot pass specialized value 0010|1020 into metadadictionary
# 439/1313 - Reading: ./in/all/AIC_07_0027/234605
# Cannot pass specialized value 0010|1020 into metadadictionary
# 440/1313 - Reading: ./in/all/AIC_07_0028/234471
# Cannot pass specialized value 0010|1020 into metadadictionary
# 441/1313 - Reading: ./in/all/AIC_07_0029/234469
# Cannot pass specialized value 0010|1020 into metadadictionary
# 442/1313 - Reading: ./in/all/AIC_07_0030/234467
# Cannot pass specialized value 0010|1020 into metadadictionary
# 443/1313 - Reading: ./in/all/AIC_07_0031/234463
# Cannot pass specialized value 0010|1020 into metadadictionary
# 444/1313 - Reading: ./in/all/AIC_07_0032/234461
# Cannot pass specialized value 0010|1020 into metadadictionary
# 445/1313 - Reading: ./in/all/AIC_07_0033/234458
# Cannot pass specialized value 0010|1020 into metadadictionary
# 446/1313 - Reading: ./in/all/AIC_07_0034/234455
# Cannot pass specialized value 0010|1020 into metadadictionary
# 447/1313 - Reading: ./in/all/AIC_07_0035/234665
# ...
# 1079/1313 - Reading: ./in/all/AIC_18_0022/316962
# 1080/1313 - Reading: ./in/all/AIC_18_0023/316963
# 1081/1313 - Reading: ./in/all/AIC_18_0024 IRM/235665
# 1082/1313 - Reading: ./in/all/AIC_18_0028/235666
# 1083/1313 - Reading: ./in/all/AIC_18_0028b/235934
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1084/1313 - Reading: ./in/all/AIC_18_0029/333541
# 1085/1313 - Reading: ./in/all/AIC_18_0030/235667
# 1086/1313 - Reading: ./in/all/AIC_18_0032/237839
# 1087/1313 - Reading: ./in/all/AIC_18_0033/237840
# 1088/1313 - Reading: ./in/all/AIC_18_0034IRM/244742
# 1089/1313 - Reading: ./in/all/AIC_18_0035IRMTOF/244747
# 1090/1313 - Reading: ./in/all/AIC_18_0036IRMTOF/244748
# 1091/1313 - Reading: ./in/all/AIC_18_0037/268550
# 1092/1313 - Reading: ./in/all/AIC_18_0039/268591
# 1093/1313 - Reading: ./in/all/AIC_18_0040 IRM TOF/252308
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1293/1313 - Reading: ./in/all/AIC_29_0003/236850
# Cannot pass specialized value 0010|1020 into metadadictionary
# 1294/1313 - Reading: ./in/all/AIC_29_0006/244044
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1295/1313 - Reading: ./in/all/AIC_29_0009/248650
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1296/1313 - Reading: ./in/all/AIC_29_0011/269811
# 1297/1313 - Reading: ./in/all/AIC_29_0014/254372
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1298/1313 - Reading: ./in/all/AIC_29_0015/254377
# Cannot pass specialized value 0010|1020 into metadadictionary
# 1299/1313 - Reading: ./in/all/AIC_29_0016/265272
# 1300/1313 - Reading: ./in/all/AIC_29_0018/265235
# Cannot pass specialized value 0010|1010 into metadadictionary
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1301/1313 - Reading: ./in/all/AIC_29_0019/288821
# 1302/1313 - Reading: ./in/all/AIC_29_0021/288887
# Cannot pass specialized value 0010|1020 into metadadictionary
# 1303/1313 - Reading: ./in/all/AIC_29_0022/288889
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1304/1313 - Reading: ./in/all/AIC_29_0024/288892
# 1305/1313 - Reading: ./in/all/AIC_29_0026/295814
# Cannot pass specialized value 0010|1020 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary
# 1306/1313 - Reading: ./in/all/AIC_29_0027/295816
# Cannot pass specialized value 0010|1020 into metadadictionary
# 1307/1313 - Reading: ./in/all/AIC_29_0028/295819
# Cannot pass specialized value 0010|1020 into metadadictionary
# 1308/1313 - Reading: ./in/all/AIC_29_0029/295821
# Cannot pass specialized value 0010|1020 into metadadictionary
# 1309/1313 - Reading: ./in/all/AIC_4_0139/320835
# Cannot pass specialized value 0010|1020 into metadadictionary
# 1310/1313 - Reading: ./in/all/ANIC_09_0026/235493
# 1311/1313 - Reading: ./in/all/ICAN_22_0043/229923
# 1312/1313 - Reading: ./in/all/UCAN_01_12/383315
# Cannot pass specialized value 0008|0080 into metadadictionary
# Cannot pass specialized value 0008|1010 into metadadictionary
# Cannot pass specialized value 0018|0025 into metadadictionary

# %% [markdown]
# ## Cluster patient according to their DICOM metadata

# %%
with open(savepath + 'headerDICOMs', 'rb') as rf:
    patients_data = pickle.load(rf)
for i in range(len(patients_data)-1, -1, -1):
    if len(patients_data[i]) == 1: del patients_data[i]
# Common keys to check
list_checkkeys = ['Modality',  'Manufacturer', 'Institution name', 'Station Name', 'Manufacturer Model Name', 'Magnetic Field Strength', ]
# Initialization
clusters = []
flag     = True
# Loop
while flag:
    patient_ref = patients_data[0]
    clusters.append([])
    list_same = [0, ]
    for i in range(1, len(patients_data)):
        same = True
        for key in list_checkkeys:
            if key in patient_ref and key in patients_data[i]:
                if patient_ref[key] != patients_data[i][key]:
                    same = False
                    break
            else:
                same = False
                break
        if same: list_same.append(i)
    list_same.reverse()
    for j in list_same:
        clusters[-1].append(patients_data[j])
        del patients_data[j]
    if len(patients_data) == 0: flag = False
print('Number of clusters: {}, max size cluster: {}'.format(len(clusters), max([len(x) for x in clusters])))
cluster_summary = []
for c in clusters:
    cluster_summary.append(dict())
    for k in list_checkkeys:
        if k in c[0].keys(): cluster_summary[-1][k] = c[0][k]
    cluster_summary[-1]['data'] = []
    for cc in c:
        cluster_summary[-1]['data'].append(dict())
        for k in cc.keys():
            if not k in list_checkkeys:
                cluster_summary[-1]['data'][-1][k] = cc[k]
# Save
with open(savepath + 'clusterDICOMs', 'wb') as wf:
    pickle.dump(cluster_summary, wf)
# Out:
# Number of clusters: 280, max size cluster: 216

# %% [markdown]
# ## Define useful keys to describe a TOF

# %%
with open(savepath + 'headerDICOMs', 'rb') as rf:
    patients_data = pickle.load(rf)
    
list_keys_prm = ['Manufacturer', 'Magnetic Field Strength',
                 'Slice Thickness',  'Spacing between Slices',  'Pixel Spacing',      # Image resolution
                 'Echo Time', 'Flip Angle', 'Scan Options']

v_prm = dict()
for key in list_keys_prm:
    v_prm[key] = []
    
for pat in patients_data:
    for key in list_keys_prm:
        if key in pat.keys():
            v_prm[key].append(pat[key])

v_prm_unique = dict()            
for key in list_keys_prm:
    v_prm_unique[key] = np.unique(v_prm[key])
# Out:
# {'Manufacturer': array(['GE MEDICAL SYSTEMS', 'Hitachi Medical Corporation ', 'MR',
#        'McKesson Medical Imaging Group', 'Philips ', 'Philips Healthcare',
#        'Philips Medical Systems ', 'SIEMENS ', 'Siemens ',
#        'Siemens HealthCare GmbH ', 'TOSHIBA '], dtype='<U30'), 'Magnetic Field Strength': array(['1 ', '1.493806', '1.4939999580383 ', '1.5 ', '15000 ', '3 ',
#        'None'], dtype='<U16'), 'Slice Thickness': array(['0.339286', '0.41999998688698', '0.4297', '0.49000000953674',
#        '0.5 ', '0.5000', '0.51999998092651', '0.52999997138977',
#        '0.53000003099442', '0.55000001192093', '0.56', '0.56999999284744',
#        '0.5799999833107 ', '0.59999996423721', '0.6000',
#        '0.60000002384186', '0.625000', '0.64999997615814', '0.65',
#        '0.65000003576279', '0.66000002622604', '0.69999998807907', '0.7 ',
#        '0.70000004768372', '0.73000001907349', '0.75', '0.79999995231628',
#        '0.8 ', '0.8000000119', '0.80000001192093', '0.84999996423721',
#        '0.85000002384186', '0.85999995470047', '0.90000003576279',
#        '001.000000E+00', '1 ', '1.1 ', '1.2 ', '1.3 ', '1.399999976 ',
#        '1.4 ', '1.6 ', '1.8 ', '10', '2 ', '4 ', 'None'], dtype='<U16'), 'Spacing between Slices': array(['0.299998', '0.299999', '0.3 ', '0.300001', '0.300003', '0.35',
#        '0.399998', '0.399999', '0.4 ', '0.400000006 ', '0.400001',
#        '0.400002', '0.499998', '0.499999', '0.5 ', '0.5000', '0.500001',
#        '0.500002', '0.55', '0.56', '0.599997', '0.599998', '0.599999',
#        '0.6 ', '0.6000', '0.600001', '0.600002', '0.625000', '0.65',
#        '0.699998', '0.699999', '0.7 ', '0.7000001669', '0.700001',
#        '0.700002', '0.799998', '0.799999', '0.8 ', '0.800001', '0.800002',
#        '0.800003', '0.899999', '0.9 ', '1 ', '10.44 ', '10.83 ', '11.34 ',
#        '11.5', '12', '12.35 ', '12.5', '13.14 ', '13.6', '13.76 ', '14',
#        '14.4', '14.5', '14.95 ', '15', '15.4', '15.6', '15.68 ', '16',
#        '16.2', '16.5', '16.8', '16.96 ', '17.4', '17.5', '17.6', '18',
#        '18.2', '18.4', '18.6', '18.85 ', '18.9', '19', '19.08 ', '19.14 ',
#        '19.2', '19.8', '20', '20.15 ', '20.3', '20.4', '20.9', '21',
#        '0.703125\\0.703125 ', '0.8594\\0.8594 ',
#        '004.101563E-01\\04.101563E-01', 'None'], dtype='<U34'), 'Echo Time': array(['006.500000E+00', '006.8 ', '008.0 ', '1.548000', '1.578000',
#        '1.8 ', '1.9 ', '10.36 ', '2 ', '2.1 ', '2.2 ', '2.3 ', '2.4 ',
#        '2.46', '2.5 ', '2.6 ', '2.7 ', '2.8 ', '2.9 ', '2.900000', '3 ',
#        '3.05', '3.1 ', '3.2 ', '3.3 ', '3.4 ', '3.42', '3.43', '3.44',
#        '3.446 ', '3.452 ', '3.45237493515014', '3.453 ', '3.454 ',
#        '3.454000', '3.455 ', '3.455000', '3.456 ', '3.459 ', '3.5 ',
#        '3.500000', '3.51', '3.6 ', '3.69', '3.690000', '3.7 ', '3.74',
#        '3.78', '3.82', '3.89', '4 ', '4.1 ', '4.2 ', '4.69', '5 ', '5.36',
#        '5.7 ', '5.755 ', '6 ', '6.3 ', '6.7 ', '6.8 ', '6.9 ', '6.900000',
#        '6.900000095 ', '6.905 ', '6.905000', '6.906 ', '6.908 ', '7 ',
#        '7.15', '7.16', '7.26', 'None'], dtype='<U16'), 'Flip Angle': array(['15', '16', '17', '18', '19', '20', '22', '23', '25', '30', 'None'],
#       dtype='<U4'), 'Scan Options': array(['', 'CG\\RG\\PER ', 'FC',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\FS',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\PFP\\SP\\FS ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\VASCTOF_GEMS\\PFF\\SP ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\HYPERSENSE_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\PFP\\SP\\FS ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\HYPERSENSE_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\PFP\\SP\\FS ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_SI_GEMS\\HYPERSENSE_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\PFP\\SP\\FS ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\PFP\\SP',
#        'FC\\SAT_GEMS\\EDR_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP',
#        'FC\\SAT_GEMS\\EDR_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS ',
#        'FC\\SAT_GEMS\\EDR_GEMS\\VASCTOF_GEMS\\PFF\\SP',
#        'FC\\SAT_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS',
#        'FC\\SAT_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\PFP\\SP\\FS',
#        'FC\\SAT_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP ',
#        'FC\\SAT_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS',
#        'FC\\SAT_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\VASCTOF_GEMS\\PFF\\SP',
#        'FC\\SAT_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS ',
#        'FC\\SAT_GEMS\\NPW\\NP\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\HYPERSENSE_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\PFP\\SP\\FS',
#        'FC\\SAT_GEMS\\RAMP_IS_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP ',
#        'FC\\SAT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\ACC_GEMS\\VASCTOF_GEMS\\PFF\\SP\\FS',
#        'FC\\SAT_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\VASCTOF_GEMS\\PFF\\SP',
#        'FC\\SAT_GEMS\\VB_GEMS\\EDR_GEMS\\MT_GEMS\\RAMP_IS_GEMS\\VASCTOF_GEMS\\PFF\\SP ',
#        'FC\\SAT_GEMS\\VB_GEMS\\RAMP_IS_GEMS\\FILTERED_GEMS\\VASCTOF_GEMS\\PFF\\SP',
#        'HELICAL MODE',
#        'IIC_GEMS\\FC\\SAT_GEMS\\VB_GEMS \\RAMP_IS_GEMS\\VASCTOF_GEMS\\PFF \\SP ',
#        'None', 'PER ', 'PFF ', 'PFP ', 'PFP\\SAT1', 'PFP\\SAT1\\MT ',
#        'SAT1', 'SAT1\\MT\\WE', 'SP', 'SP\\FC '], dtype='<U114')}

# %% [markdown]
# ## Display info in a dynamic table

# %%
import tkinter as tk
from tkinter import ttk

# Define content of the columns
cols  = ['#', 'file',] + list_keys_prm

# Define the window and frame
parent = tk.Tk()
parent.geometry('1000x600')
frame  = tk.Frame(parent, width=1000, height=400, relief="groove") #, bg="red")
frame.pack(fill='both', expand=True) # fill='x'

# Define function to get the info from patients_data
def getInfo():
    # Delete old display
    selected_item = table.get_children()
    if len(selected_item) > 0:
        for itm in selected_item:
            table.delete(itm)
    #
    l_check = []
    l_keep  = []
    display = ''
    for v in tkvar:
        l_check.append(v.get())
    l_ck = [l_k[k] for k in range(len(l_k)) if l_check[k]]
    l_cv = [l_v[k] for k in range(len(l_v)) if l_check[k]]
    l_uk = np.unique(l_k)
    for i, pat in enumerate(patients_data):
        flag = True
        for l in l_uk:
            aux = [l_cv[k] for k in range(len(l_cv)) if l_ck[k] == l]
            if aux:
                if (l not in pat) or (not any(pat[l] == np.array(aux))):
                    flag = False
        if flag and any(np.array(l_check)):
            row = [i, ] + [pat[k] for k in cols[1:]]
            table.insert("", "end", values=row)

# Define the Table
table = ttk.Treeview(frame, columns=cols, height=25, show='headings')
for col in cols:
    table.heading(col, text=col)    
table.grid(row=1, column=0, columnspan=len(cols), sticky='nsew')
# Define the scrollbar
scrollbar = tk.Scrollbar(frame, orient="vertical", command=table.yview)
scrollbar.grid(row=1, column=len(cols)+1, sticky='ns')
table.configure(yscrollcommand=scrollbar.set)
# Define the label
label = tk.Label(frame, text="Variables", font=("Arial",15)).grid(row=0, columnspan=3)
# Handle the menu with check boxes
menubar = tk.Menu(parent)
menu  = []
tkvar = []
l_k   = []
l_v   = []
for key in list_keys_prm:
    menu.append(tk.Menu(menubar))
    for value in v_prm_unique[key]: #v_prm_ext
        tkvar.append(tk.BooleanVar())
        tkvar[-1].set(False)
        menu[-1].add_checkbutton(label=str(value), onvalue=1, offvalue=0, variable=tkvar[-1], command=getInfo)
        l_v.append(value)
        l_k.append(key)
    menubar.add_cascade(label=key, menu=menu[-1])
parent.config(menu=menubar)
# Fit the table to the window
frame.columnconfigure(1, weight=1)
frame.rowconfigure(1, weight=1)
# Main loop
parent.mainloop()

# To get the right layout, use in full screen, then the table will be resized according to the window's size

# %% [markdown]
# Warning concerning Slice Thickness and Spacing between Slices: https://stackoverflow.com/a/14944200
#
# http://mriquestions.com/cross-talk.html# :
# "The major MR vendors use slightly different terminologies to refer to this interslice spacing. GE, Philips, and Canon use the generic term "gap" that is prescribed in mm, while Hitachi uses the term "slice interval". Siemens specifies the slice gap indirectly, calling it the "distance factor". Siemens' "distance factor" is specified as a percentage of slice thickness rather than actual distance. So a distance factor of 20% applied to a group of 5-mm-thick slices means there is a 1-mm gap between them."

# %% [markdown]
# # ---- Old -------

# %%
#v_prm_ind = dict()

#for key in list_keys_prm:
#    v_prm_ind[key] = []
#    if not key in ['Manufacturer', 'Scan Options']:
#        loc_lis = v_prm_ext[key]
#        for lis_val in loc_lis:
#            v_prm_ind[key].append([])
#            loc_val = float(lis_val.split('\\')[0])
#            for i, pat in enumerate(patients_data):
#                if key in pat.keys():
#                    pat_val = float(pat[key].split('\\')[0])
#                    if pat_val > loc_val*0.95 and pat_val < loc_val*1.05:
#                        v_prm_ind[key][-1].append(i)
#            
#print(v_prm_ind)
